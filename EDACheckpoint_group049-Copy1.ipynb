# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Abdalla Atalla
# - Che-Yu Hou
# - Jason Wong
# - Tsun Wai Siu
# - William Chai

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# In the United States of America, is there a relationship between the consumer age and their consumption of avocados? More specifically, does younger populations consume more avocados than older populations or vice versa.

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sns
 
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style

import statsmodels.api as sm
import patsy

sns.set(font_scale=2, style="white")
# %config InlineBackend.figure_format = 'retina'

# %%
sales2018 = pd.read_csv('https://raw.githubusercontent.com/COGS108/group049_wi21/main/Hass%20Sales%20Data%20in%20USA%202018.csv?token=ALZLNVNKDL45GSY3VTO7RR3AJLOEO')
sales2019 = pd.read_csv('https://raw.githubusercontent.com/COGS108/group049_wi21/main/Hass%20Sales%20Data%20in%20USA%202019.csv?token=ALZLNVMIJRVMGJONJ7DW6UTAJLODK')
sales2020 = pd.read_csv('https://raw.githubusercontent.com/COGS108/group049_wi21/main/Hass%20Sales%20Data%20in%20USA%202020.csv?token=ALZLNVNRJHV6WYUDH64DALDAJLOBA')
population = pd.read_csv('https://raw.githubusercontent.com/COGS108/group049_wi21/main/City%20Population%20by%20Age%20by%20US%20Census%202019.csv?token=ALZLNVN7SGRHWTFQJBZRIILAJLN5U')
income =  pd.read_csv('https://raw.githubusercontent.com/COGS108/group049_wi21/main/Median%20income%20by%20City%202019.csv?token=ALZLNVPSYGZYGSDZKD2MME3AJLM6E')

# vol2018 = pd.read_csv('https://raw.githubusercontent.com/COGS108/group049_wi21/main/Hass%20Volume%20Data%202018.csv?token=ALZLNVJXOJ27QI5BCQH6XLDAIBKZC')
# vol2019 = pd.read_csv('https://raw.githubusercontent.com/COGS108/group049_wi21/main/Hass%20Volume%20Data%202019.csv?token=ALZLNVOND6JZLFY4QRDSNK3AIBK4Q')
# vol2020 = pd.read_csv('https://raw.githubusercontent.com/COGS108/group049_wi21/main/Hass%20Volume%20Data%202020.csv?token=ALZLNVKBSAE5LQIT643Q52DAIBNW6')

# %% [markdown]
# # Dataset (s)

# %% [markdown]
# Dataset Name: United States Census Population by Age 2019 <br>
# Link to the dataset: https://data.census.gov/cedsci/table?g=1600000US0455000,0644000,0664000,0666000,0667000,0820000,1235000,1245000,1253000,1271000,1304000,1608830,1714000,1836003,2148000,2255000,2507000,2622000,2634000,2965000,3240000,3601000,3651000,3673000,3712000,3755000,3918000,4159000,4260000,4261000,4819000,4835000,5157000,5168000,5363000,5367000&tid=ACSST5Y2019.S0101&moe=false&hidePreview=true <br>
# Number of observations: 35 <br>
# This data is gathered by the United States Census Bureau in 2019. The United States Census is collected and compiled every 10 years. The data set represents various cities’ population, broken down by age groups. We only downloaded data from cities that we have data on their avocado sales. <br>
# <br>
# Dataset Name: Avocado Category Data <br>
# Link to the dataset: https://hassavocadoboard.com/category-data/<br>
# Number of observations: 16092<br>
# This data is gathered from the Hass Avocado Board and compiled into a dataset. The data set represents weekly retail sales data for small, large, and extra large Hass avocados in volume and price from 2015-2018. Hass Avocado Board describes retail as “grocery, mass, club, drug, dollar, and military [stores]”.<br>

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# We first take a look at our sales dataset.

# %%
sales2018.head()
# Out:
#               Geography Timeframe Current Year Week Ending          Type  \
# 0                Albany    Weekly      2018-01-01 00:00:00  Conventional
# 1               Atlanta    Weekly      2018-01-01 00:00:00  Conventional
# 2  Baltimore/Washington    Weekly      2018-01-01 00:00:00  Conventional
# 3                 Boise    Weekly      2018-01-01 00:00:00  Conventional
# 4                Boston    Weekly      2018-01-01 00:00:00  Conventional
#
#    ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 0              1.47                  113514.42     2622.70   101135.53
# 1              0.95                  649352.59   341061.46    41818.27
# 2              1.15                  849487.62    66628.66   519460.20
# 3              1.13                   79646.97    38196.44     1706.22
# 4              1.40                  419696.59     9622.52   325398.02
#
#    4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# 0       20.25            9735.94          5556.98          4178.96
# 1      961.18          265511.68        173990.02         88882.27
# 2     4920.46          258478.30        245665.84         12812.46
# 3     6263.00           33481.31         28764.84          4676.67
# 4     2061.91           82614.14         65868.23         16745.91
#
#    X-LrgBagged Units
# 0               0.00
# 1            2639.39
# 2               0.00
# 3              39.80
# 4               0.00

# %% [markdown]
# We are not interested in 'Timeframe', as we already knew our data is reported weekly. We are also dropping 'Total Bulk and Bags Units', 'SmlBagged Units','LrgBagged Units','X-LrgBagged Units', and 'TotalBagged Units' because we have 'ASP' which stands for the average price of a single avocado. Since there is no way to tell how many avocados are in a bag or bulk unit, we will not be using those columns.

# %%
sales2018 = sales2018.drop(['Timeframe','Total Bulk and Bags Units','SmlBagged Units','LrgBagged Units','X-LrgBagged Units','TotalBagged Units'],axis=1)
sales2018.head()
# Out:
#               Geography Current Year Week Ending          Type  \
# 0                Albany      2018-01-01 00:00:00  Conventional
# 1               Atlanta      2018-01-01 00:00:00  Conventional
# 2  Baltimore/Washington      2018-01-01 00:00:00  Conventional
# 3                 Boise      2018-01-01 00:00:00  Conventional
# 4                Boston      2018-01-01 00:00:00  Conventional
#
#    ASP Current Year  4046 Units  4225 Units  4770 Units
# 0              1.47     2622.70   101135.53       20.25
# 1              0.95   341061.46    41818.27      961.18
# 2              1.15    66628.66   519460.20     4920.46
# 3              1.13    38196.44     1706.22     6263.00
# 4              1.40     9622.52   325398.02     2061.91

# %% [markdown]
# Now that we had dropped all the columns we do not need for this project. We continue to look for values that need cleaning. Since we know this dataframe represents sales data for 2018, then '2018' under 'Current Year Week Ending' is redundant and shall be dropped. 'Current Year Week Ending' also contains a generic timestamp '00:00:00', which we will be dropping as well. We decided to keep our 'Current Year Week Ending' in M/D format, we wrote a function to change the date format as shown in code below. We also decided to change column name to make it more concise.

# %%
def standardizeDat(var):
    var = var.replace('2018-','').replace('-','/').replace(':','')
    month = var.split('/',1)[0]
    date = var.split('/',1)[1]
    
    if(month != '10'):
        month = month.replace('0','')
    if(date != '10' or date != '20' or date != '30'):
        date = date.replace('0','')
    string = month+ '/'+ date
    return string.strip()

def standardizeType(string):
    string = string.strip()
    return string
    
sales2018['Type'] = sales2018['Type'].apply(standardizeType)
sales2018['Current Year Week Ending'] = sales2018['Current Year Week Ending'].apply(standardizeDat)
sales2018 = sales2018.rename(columns={'Current Year Week Ending': "Week Ending"})
sales2018 = sales2018.rename(columns={'Geography': "City"})
sales2018 = sales2018.rename(columns={'ASP Current Year': "Average Price Per Unit"})

sales2018['Total Sales ($)'] = (sales2018['4046 Units'] + sales2018['4225 Units'] + sales2018['4770 Units']) * sales2018['Average Price Per Unit']


sales2018.head()
# Out:
#                    City Week Ending          Type  Average Price Per Unit  \
# 0                Albany         1/1  Conventional                    1.47
# 1               Atlanta         1/1  Conventional                    0.95
# 2  Baltimore/Washington         1/1  Conventional                    1.15
# 3                 Boise         1/1  Conventional                    1.13
# 4                Boston         1/1  Conventional                    1.40
#
#    4046 Units  4225 Units  4770 Units  Total Sales ($)
# 0     2622.70   101135.53       20.25      152554.3656
# 1   341061.46    41818.27      961.18      364648.8645
# 2    66628.66   519460.20     4920.46      679660.7180
# 3    38196.44     1706.22     6263.00       52167.1958
# 4     9622.52   325398.02     2061.91      471915.4300

# %% [markdown]
# We repeat the cleaning process for sales2019 and sales2020. We first take a look at sales2019.

# %%
sales2019.head()
# Out:
#               Geography Timeframe Current Year Week Ending          Type  \
# 0            Total U.S.    Weekly            1/7/2019 0:00  Conventional
# 1                Albany    Weekly            1/7/2019 0:00  Conventional
# 2               Atlanta    Weekly            1/7/2019 0:00  Conventional
# 3  Baltimore/Washington    Weekly            1/7/2019 0:00  Conventional
# 4                 Boise    Weekly            1/7/2019 0:00  Conventional
#
#    ASP Current Year  Total Bulk and Bags Units   4046 Units   4225 Units  \
# 0              1.02                44749707.48  14377053.08  11890232.90
# 1              1.07                  129222.29      3789.30    112635.18
# 2              0.92                  828971.15    388574.98     38902.85
# 3              1.31                  925391.38    102652.85    530128.43
# 4              1.23                  108261.98     43723.19      7085.86
#
#    4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# 0   893721.10        17588700.40      12829493.40       4617813.55
# 1      158.00           12639.81          8877.95          3761.86
# 2     3482.04          398011.28        299475.26         98477.41
# 3     8212.94          284397.16        263150.78         21233.05
# 4    14435.46           43017.47         23932.54         19049.95
#
#    X-LrgBagged Units
# 0          141393.45
# 1               0.00
# 2              58.61
# 3              13.33
# 4              34.98

# %% [markdown]
# We drop the same columns as we did for sales2018, format change column 'Current Year Week Ending' to 'Week Ending', and format it date to keep it uniform throughout the project.

# %%
def standardizeDate(string):
    var = string.split(' ', 1)[0]
    var = var.split('/')
    var = var[0]+'/'+var[1]
    return var.strip()


    
sales2019['Type'] = sales2019['Type'].apply(standardizeType)
sales2019 = sales2019.drop(['Timeframe','Total Bulk and Bags Units','SmlBagged Units','LrgBagged Units','X-LrgBagged Units','TotalBagged Units'],axis=1)
sales2019['Current Year Week Ending'] = sales2019['Current Year Week Ending'].apply(standardizeDate)
sales2019 = sales2019.rename(columns={'Current Year Week Ending': "Week Ending"})
sales2019 = sales2019.rename(columns={'Geography': "City"})
sales2019 = sales2019.rename(columns={'ASP Current Year': "Average Price Per Unit"})

sales2019['Total Sales ($)'] = (sales2019['4046 Units'] + sales2019['4225 Units'] + sales2019['4770 Units']) * sales2019['Average Price Per Unit']


sales2019.head()
# Out:
#                    City Week Ending          Type  Average Price Per Unit  \
# 0            Total U.S.         1/7  Conventional                    1.02
# 1                Albany         1/7  Conventional                    1.07
# 2               Atlanta         1/7  Conventional                    0.92
# 3  Baltimore/Washington         1/7  Conventional                    1.31
# 4                 Boise         1/7  Conventional                    1.23
#
#     4046 Units   4225 Units  4770 Units  Total Sales ($)
# 0  14377053.08  11890232.90   893721.10     2.770423e+07
# 1      3789.30    112635.18      158.00     1.247433e+05
# 2    388574.98     38902.85     3482.04     3.964831e+05
# 3    102652.85    530128.43     8212.94     8.397024e+05
# 4     43723.19      7085.86    14435.46     8.025075e+04

# %%
sales2020.head()
# Out:
#               Geography Timeframe Current Year Week Ending           Type  \
# 0                Albany    Weekly            1/6/2020 0:00  Conventional
# 1               Atlanta    Weekly            1/6/2020 0:00  Conventional
# 2  Baltimore/Washington    Weekly            1/6/2020 0:00  Conventional
# 3                 Boise    Weekly            1/6/2020 0:00  Conventional
# 4                Boston    Weekly            1/6/2020 0:00  Conventional
#
#    ASP Current Year  Total Bulk and Bags Units  4046 Units  4225 Units  \
# 0              0.92                  185688.43     4038.61   163629.86
# 1              0.89                  812755.45   355460.73    37303.12
# 2              1.13                 1040583.36   120288.69   522244.65
# 3              1.09                  121921.10    35816.52     8749.59
# 4              1.18                  762475.92    11242.17   494342.34
#
#    4770 Units  TotalBagged Units  SmlBagged Units  LrgBagged Units  \
# 0      193.31           17826.65          7098.37          9384.95
# 1     2905.78          417085.82        371318.63         45627.67
# 2     6213.88          391836.14        239052.24        152663.90
# 3     1834.52           75520.47         39530.82         31962.59
# 4     1486.19          255405.22        110420.12        144661.77
#
#    X-LrgBagged Units
# 0            1343.33
# 1             139.52
# 2             120.00
# 3            4027.06
# 4             323.33

# %%
sales2020 = sales2020.drop(['Timeframe','Total Bulk and Bags Units','SmlBagged Units','LrgBagged Units','X-LrgBagged Units','TotalBagged Units'],axis=1)
sales2020['Type'] = sales2020['Type'].apply(standardizeType)
sales2020['Current Year Week Ending'] = sales2020['Current Year Week Ending'].apply(standardizeDate)
sales2020 = sales2020.rename(columns={'Current Year Week Ending': "Week Ending"})
sales2020 = sales2020.rename(columns={'Geography': "City"})
sales2020 = sales2020.rename(columns={'ASP Current Year': "Average Price Per Unit"})

sales2020['Total Sales ($)'] = (sales2020['4046 Units'] + sales2020['4225 Units'] + sales2020['4770 Units']) * sales2020['Average Price Per Unit']

sales2020.head()
# Out:
#                    City Week Ending          Type  Average Price Per Unit  \
# 0                Albany         1/6  Conventional                    0.92
# 1               Atlanta         1/6  Conventional                    0.89
# 2  Baltimore/Washington         1/6  Conventional                    1.13
# 3                 Boise         1/6  Conventional                    1.09
# 4                Boston         1/6  Conventional                    1.18
#
#    4046 Units  4225 Units  4770 Units  Total Sales ($)
# 0     4038.61   163629.86      193.31      154432.8376
# 1   355460.73    37303.12     2905.78      352145.9707
# 2   120288.69   522244.65     6213.88      733084.3586
# 3    35816.52     8749.59     1834.52       50576.6867
# 4    11242.17   494342.34     1486.19      598343.4260

# %%
# def standardizeDate2(string):
#     string = string.split(',', 1)[0]
#     string = string.replace('Jan','1')
#     string = string.replace('Feb','2')
#     string = string.replace('Mar','3')
#     string = string.replace('Apr','4')
#     string = string.replace('May','5')
#     string = string.replace('Jun','6')
#     string = string.replace('Jul','7')
#     string = string.replace('Aug','8')
#     string = string.replace('Sep','9')
#     string = string.replace('Oct','10')
#     string = string.replace('Nov','11')
#     string = string.replace('Dec','12')
#     string = string.replace(' ', '/')
#     return string.strip()

# vol2019 = vol2019.drop(['Year','Status'],axis=1)
# vol2019['Week'] = vol2019['Week'].apply(standardizeDate2)
# vol2019.head()

# %% [markdown]
# We now take a look at our population dataframe.

# %%
population.head()
# Out:
#               City            State Total population Under 5 years  \
# 0      Albany city         New York           97,478         5,622
# 1     Atlanta city          Georgia          488,800        26,577
# 2  Boise City city            Idaho          226,115        12,985
# 3      Boston city    Massachusetts          684,379        34,485
# 4   Charlotte city   North Carolina          857,425        57,891
#
#   5 to 9 years 10 to 14 years 15 to 19 years 20 to 24 years 25 to 29 years  \
# 0        4,667          4,431          8,570         15,224          8,261
# 1       27,559         22,290         32,902         48,054         55,760
# 2       13,588         14,017         15,230         17,016         18,194
# 3       28,298         28,621         48,283         70,917         94,816
# 4       56,536         56,238         53,321         60,169         79,999
#
#   30 to 34 years  ... 65 to 69 years 70 to 74 years 75 to 79 years  \
# 0          7,448  ...          3,925          3,032          1,885
# 1         46,168  ...         18,172         14,829          9,696
# 2         17,110  ...         11,677          7,313          4,825
# 3         72,051  ...         25,139         20,019         13,703
# 4         74,831  ...         31,485         23,228         13,825
#
#   80 to 84 years 85 years and over Median age (years)  \
# 0          1,620             2,139               30.9
# 1          6,821             6,780               33.3
# 2          3,629             4,054               36.6
# 3          9,116            10,884               32.2
# 4          9,771             9,431               34.2
#
#   Sex ratio (males per 100 females) Age dependency ratio  \
# 0                              88.3                 44.2
# 1                              94.3                 42.4
# 2                              99.3                 55.6
# 3                              92.3                 37.8
# 4                              92.5                 51.3
#
#   Old-age dependency ratio Child dependency ratio
# 0                     18.6                   25.6
# 1                     16.4                   26.0
# 2                     21.7                   33.9
# 3                     15.9                   22.0
# 4                     15.5                   35.8
#
# [5 rows x 26 columns]

# %%
population.dtypes
# Out:
# City                                  object
# State                                 object
# Total population                      object
# Under 5 years                         object
# 5 to 9 years                          object
# 10 to 14 years                        object
# 15 to 19 years                        object
# 20 to 24 years                        object
# 25 to 29 years                        object
# 30 to 34 years                        object
# 35 to 39 years                        object
# 40 to 44 years                        object
# 45 to 49 years                        object
# 50 to 54 years                        object
# 55 to 59 years                        object
# 60 to 64 years                        object
# 65 to 69 years                        object
# 70 to 74 years                        object
# 75 to 79 years                        object
# 80 to 84 years                        object
# 85 years and over                     object
# Median age (years)                   float64
# Sex ratio (males per 100 females)    float64
# Age dependency ratio                 float64
# Old-age dependency ratio             float64
# Child dependency ratio               float64
# dtype: object

# %% [markdown]
# As we can see after we ran population.dtypes, many of our data have incorrect data type. We would like the population to be represented by integer data type instead of object type. We also noticed that there is an unnecessary word 'city' that follows each city name, thus we will be dropping those using function "standardizeCity" we have created.

# %%
def standardizeCity(string):
    string = string.replace('city',"")
    string = string.strip()
    return string

def stripBalance(string):
    string = string.replace('(balance)',"")
    string = string.strip()
    return string

population = population.drop(['Age dependency ratio','Old-age dependency ratio','Child dependency ratio'],axis=1)

population['City'] = population['City'].apply(standardizeCity)
population['City'] = population['City'].apply(stripBalance)
population['Total population'] = (pd.to_numeric(population['Total population'].str.replace(',',''), errors='coerce')).astype(int)
population['Under 5 years'] = (pd.to_numeric(population['Under 5 years'].str.replace(',',''), errors='coerce')).astype(int)
population['5 to 9 years'] = (pd.to_numeric(population['5 to 9 years'].str.replace(',',''), errors='coerce')).astype(int)
population['10 to 14 years'] = (pd.to_numeric(population['10 to 14 years'].str.replace(',',''), errors='coerce')).astype(int)
population['15 to 19 years'] = (pd.to_numeric(population['15 to 19 years'].str.replace(',',''), errors='coerce')).astype(int)
population['20 to 24 years'] = (pd.to_numeric(population['20 to 24 years'].str.replace(',',''), errors='coerce')).astype(int)
population['25 to 29 years'] = (pd.to_numeric(population['25 to 29 years'].str.replace(',',''), errors='coerce')).astype(int)
population['30 to 34 years'] = (pd.to_numeric(population['30 to 34 years'].str.replace(',',''), errors='coerce')).astype(int)
population['35 to 39 years'] = (pd.to_numeric(population['35 to 39 years'].str.replace(',',''), errors='coerce')).astype(int)
population['40 to 44 years'] = (pd.to_numeric(population['40 to 44 years'].str.replace(',',''), errors='coerce')).astype(int)
population['45 to 49 years'] = (pd.to_numeric(population['45 to 49 years'].str.replace(',',''), errors='coerce')).astype(int)
population['50 to 54 years'] = (pd.to_numeric(population['50 to 54 years'].str.replace(',',''), errors='coerce')).astype(int)
population['55 to 59 years'] = (pd.to_numeric(population['55 to 59 years'].str.replace(',',''), errors='coerce')).astype(int)
population['60 to 64 years'] = (pd.to_numeric(population['60 to 64 years'].str.replace(',',''), errors='coerce')).astype(int)
population['65 to 69 years'] = (pd.to_numeric(population['65 to 69 years'].str.replace(',',''), errors='coerce')).astype(int)
population['70 to 74 years'] = (pd.to_numeric(population['70 to 74 years'].str.replace(',',''), errors='coerce')).astype(int)
population['75 to 79 years'] = (pd.to_numeric(population['75 to 79 years'].str.replace(',',''), errors='coerce')).astype(int)
population['80 to 84 years'] = (pd.to_numeric(population['80 to 84 years'].str.replace(',',''), errors='coerce')).astype(int)
population['85 years and over'] = (pd.to_numeric(population['85 years and over'].str.replace(',',''), errors='coerce')).astype(int)

population.head()
# Out:
#          City            State  Total population  Under 5 years  5 to 9 years  \
# 0      Albany         New York             97478           5622          4667
# 1     Atlanta          Georgia            488800          26577         27559
# 2  Boise City            Idaho            226115          12985         13588
# 3      Boston    Massachusetts            684379          34485         28298
# 4   Charlotte   North Carolina            857425          57891         56536
#
#    10 to 14 years  15 to 19 years  20 to 24 years  25 to 29 years  \
# 0            4431            8570           15224            8261
# 1           22290           32902           48054           55760
# 2           14017           15230           17016           18194
# 3           28621           48283           70917           94816
# 4           56238           53321           60169           79999
#
#    30 to 34 years  ...  50 to 54 years  55 to 59 years  60 to 64 years  \
# 0            7448  ...            5467            5059            5020
# 1           46168  ...           27719           26051           21839
# 2           17110  ...           13722           14088           13080
# 3           72051  ...           37588           36690           31914
# 4           74831  ...           53923           49587           41950
#
#    65 to 69 years  70 to 74 years  75 to 79 years  80 to 84 years  \
# 0            3925            3032            1885            1620
# 1           18172           14829            9696            6821
# 2           11677            7313            4825            3629
# 3           25139           20019           13703            9116
# 4           31485           23228           13825            9771
#
#    85 years and over  Median age (years)  Sex ratio (males per 100 females)
# 0               2139                30.9                               88.3
# 1               6780                33.3                               94.3
# 2               4054                36.6                               99.3
# 3              10884                32.2                               92.3
# 4               9431                34.2                               92.5
#
# [5 rows x 23 columns]

# %% [markdown]
# After inspecting our dataset 'Population', we found that there are cities in 'sales2018', 'sales2019', and 'sales2020' that we do not have data for in dataset 'Population'. Therefore, we will be dropping the cities from the sales dataset.

# %%
dataF = sales2018
indexNames = dataF[
    (dataF['City']=='Louisville') | 
    (dataF['City']=='Total U.S.') |
    (dataF['City']=='Baltimore/Washington') | 
    (dataF['City']=='Buffalo/Rochester') |
    (dataF['City']=='California') |
    (dataF['City']=='Cincinnati/Dayton') |
    (dataF['City']=='Great Lakes') |
    (dataF['City']=='Harrisburg/Scranton') |
    (dataF['City']=='Hartford/Springfield') |
    (dataF['City']=='Midsouth') |
    (dataF['City']=='Nashville') |
    (dataF['City']=='Northeast') |
    (dataF['City']=='Northern New England') |
    (dataF['City']=='Plains') |
    (dataF['City']=='South Carolina') |
    (dataF['City']=='South Central') |
    (dataF['City']=='Southeast') |
    (dataF['City']=='West') |
    (dataF['City']=='West Tex/New Mexico')
].index

sales2018.drop(indexNames, inplace = True)
sales2018 = sales2018.reset_index().drop(columns='index')

dataF = sales2019
indexNames = dataF[
    (dataF['City']=='Louisville') | 
    (dataF['City']=='Total U.S.') |
    (dataF['City']=='Baltimore/Washington') | 
    (dataF['City']=='Buffalo/Rochester') |
    (dataF['City']=='California') |
    (dataF['City']=='Cincinnati/Dayton') |
    (dataF['City']=='Great Lakes') |
    (dataF['City']=='Harrisburg/Scranton') |
    (dataF['City']=='Hartford/Springfield') |
    (dataF['City']=='Midsouth') |
    (dataF['City']=='Nashville') |
    (dataF['City']=='Northeast') |
    (dataF['City']=='Northern New England') |
    (dataF['City']=='Plains') |
    (dataF['City']=='South Carolina') |
    (dataF['City']=='South Central') |
    (dataF['City']=='Southeast') |
    (dataF['City']=='West') |
    (dataF['City']=='West Tex/New Mexico')
].index

sales2019.drop(indexNames, inplace = True)
sales2019 = sales2019.reset_index().drop(columns='index')


dataF = sales2020
indexNames = dataF[
    (dataF['City']=='Louisville') | 
    (dataF['City']=='Total U.S.') |
    (dataF['City']=='Baltimore/Washington') | 
    (dataF['City']=='Buffalo/Rochester') |
    (dataF['City']=='California') |
    (dataF['City']=='Cincinnati/Dayton') |
    (dataF['City']=='Great Lakes') |
    (dataF['City']=='Harrisburg/Scranton') |
    (dataF['City']=='Hartford/Springfield') |
    (dataF['City']=='Midsouth') |
    (dataF['City']=='Nashville') |
    (dataF['City']=='Northeast') |
    (dataF['City']=='Northern New England') |
    (dataF['City']=='Plains') |
    (dataF['City']=='South Carolina') |
    (dataF['City']=='South Central') |
    (dataF['City']=='Southeast') |
    (dataF['City']=='West') |
    (dataF['City']=='West Tex/New Mexico')
].index

sales2020.drop(indexNames, inplace = True)
sales2020 = sales2020.reset_index().drop(columns='index')

# %% [markdown]
# We also notice some of the cities included vicinity cities. Here, we will take the city which we have the data for in population.

# %%
def standardizeSalesCity(string):
    string = string.replace('Richmond/Norfolk',"Norfolk")
    string = string.replace('Raleigh/Greensboro',"Raleigh")
    string = string.replace('New Orleans/Mobile',"New Orleans")
    string = string.replace('Dallas/Ft. Worth',"Dallas")
    string = string.replace('Miami/Ft. Lauderdale',"Miami")
    string = string.replace('Phoenix/Tucson',"Phoenix")
    string = string.replace('Boise',"Boise City")
    string = string.strip()
    return string

sales2018['City'] = sales2018['City'].apply(standardizeSalesCity)
sales2019['City'] = sales2019['City'].apply(standardizeSalesCity)
sales2020['City'] = sales2020['City'].apply(standardizeSalesCity)

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# We like to see the distribution of population's median age of the cities that we observed.

# %%
population.head()
# Out:
#          City            State  Total population  Under 5 years  5 to 9 years  \
# 0      Albany         New York             97478           5622          4667
# 1     Atlanta          Georgia            488800          26577         27559
# 2  Boise City            Idaho            226115          12985         13588
# 3      Boston    Massachusetts            684379          34485         28298
# 4   Charlotte   North Carolina            857425          57891         56536
#
#    10 to 14 years  15 to 19 years  20 to 24 years  25 to 29 years  \
# 0            4431            8570           15224            8261
# 1           22290           32902           48054           55760
# 2           14017           15230           17016           18194
# 3           28621           48283           70917           94816
# 4           56238           53321           60169           79999
#
#    30 to 34 years  ...  50 to 54 years  55 to 59 years  60 to 64 years  \
# 0            7448  ...            5467            5059            5020
# 1           46168  ...           27719           26051           21839
# 2           17110  ...           13722           14088           13080
# 3           72051  ...           37588           36690           31914
# 4           74831  ...           53923           49587           41950
#
#    65 to 69 years  70 to 74 years  75 to 79 years  80 to 84 years  \
# 0            3925            3032            1885            1620
# 1           18172           14829            9696            6821
# 2           11677            7313            4825            3629
# 3           25139           20019           13703            9116
# 4           31485           23228           13825            9771
#
#    85 years and over  Median age (years)  Sex ratio (males per 100 females)
# 0               2139                30.9                               88.3
# 1               6780                33.3                               94.3
# 2               4054                36.6                               99.3
# 3              10884                32.2                               92.3
# 4               9431                34.2                               92.5
#
# [5 rows x 23 columns]

# %%
### City vs Median age
population = population.sort_values(by=['Median age (years)'])
sns.set(rc={'figure.figsize':(20,20)})
sns.barplot(x="Median age (years)", y="City", data=population, orient="h")
plt.show()

# %% [markdown]
# We are interested to see that cities with the highest median age and cities with the lowest median age, as these are the polarized values of our dataset. We see that the dataset has a good distribution.
#
# Since the sales data we have are weekly, we would like to know the total sales for the whole year. Thus, we group the datasets by 'City'. The 'Average Price Per Unit' were summed as well in this process, we divide it by the number of occurence of each city to get the average price of avocado of the entire year.

# %%
salesSum2018= sales2018.groupby(by=['City']).sum()
salesSum2019= sales2019.groupby(by=['City']).sum()
salesSum2020= sales2020.groupby(by=['City']).sum()

salesSum2018['Average Price Per Unit'] = salesSum2018['Average Price Per Unit']/ len(sales2018[sales2018['City']=='Albany'])
salesSum2019['Average Price Per Unit'] = salesSum2019['Average Price Per Unit']/ len(sales2019[sales2019['City']=='Albany'])
salesSum2020['Average Price Per Unit'] = salesSum2020['Average Price Per Unit'] / len(sales2020[sales2020['City']=='Albany'])

salesSum2018.head()
# Out:
#             Average Price Per Unit   4046 Units   4225 Units  4770 Units  \
# City
# Albany                    1.449592    497480.02   4692216.20     4819.64
# Atlanta                   1.282551  15428397.72   2166006.24    83442.63
# Boise City                1.538469   2013969.60    258131.73   508002.04
# Boston                    1.496429    946726.24  27194280.82    96489.39
# Charlotte                 1.537959   3844462.17   4118411.20   297824.18
#
#             Total Sales ($)
# City
# Albany         6.745543e+06
# Atlanta        1.754785e+07
# Boise City     3.428669e+06
# Boston         3.667767e+07
# Charlotte      1.033604e+07

# %%
result2018 = pd.merge(left=salesSum2018, right=population, how="left", on=["City"])
result2018 = result2018.dropna()
result2018['Sales per 100K'] = result2018['Total Sales ($)'] / (result2018['Total population']) * 100000

result2019 = pd.merge(left=salesSum2019, right=population, how="left", on=["City"])
result2019 = result2019.dropna()
result2019['Sales per 100K'] = result2019['Total Sales ($)'] / (result2019['Total population']) * 100000

result2020 = pd.merge(left=salesSum2020, right=population, how="left", on=["City"])
result2020 = result2020.dropna()
result2020['Sales per 100K'] = result2020['Total Sales ($)'] / (result2020['Total population']) * 100000
result2020.head()
# Out:
#          City  Average Price Per Unit   4046 Units   4225 Units  4770 Units  \
# 0      Albany                1.346875    459280.28   5566694.14     9244.96
# 1     Atlanta                1.207813  18429437.70   1608588.90    19030.56
# 2  Boise City                1.416979   1822009.32    423510.81    74476.34
# 3      Boston                1.603750    972456.99  24013739.81    30757.24
# 4   Charlotte                1.339271   7650208.66   3079177.77   224453.13
#
#    Total Sales ($)            State  Total population  Under 5 years  \
# 0     6.994118e+06         New York             97478           5622
# 1     1.837545e+07          Georgia            488800          26577
# 2     2.652730e+06            Idaho            226115          12985
# 3     3.386215e+07    Massachusetts            684379          34485
# 4     1.226594e+07   North Carolina            857425          57891
#
#    5 to 9 years  ...  55 to 59 years  60 to 64 years  65 to 69 years  \
# 0          4667  ...            5059            5020            3925
# 1         27559  ...           26051           21839           18172
# 2         13588  ...           14088           13080           11677
# 3         28298  ...           36690           31914           25139
# 4         56536  ...           49587           41950           31485
#
#    70 to 74 years  75 to 79 years  80 to 84 years  85 years and over  \
# 0            3032            1885            1620               2139
# 1           14829            9696            6821               6780
# 2            7313            4825            3629               4054
# 3           20019           13703            9116              10884
# 4           23228           13825            9771               9431
#
#    Median age (years)  Sex ratio (males per 100 females)  Sales per 100K
# 0                30.9                               88.3    7.175074e+06
# 1                33.3                               94.3    3.759298e+06
# 2                36.6                               99.3    1.173177e+06
# 3                32.2                               92.3    4.947865e+06
# 4                34.2                               92.5    1.430556e+06
#
# [5 rows x 29 columns]

# %% [markdown]
# We merge dataframe 'population' with 'salesSum' for 2018,2019,and 2020. We use 'City' as the key. Since every cities have different number of people, we think it is best to capture the sales data per capita. We then graph a bargraph using median age vs sales per 100k people. We hope to see an uneven distribution among the sales in each cities.

# %%
### BarGraph City vs Sales per 100K in year
result2018.plot(
    y = 'Sales per 100K',
    x = 'City',
    kind='bar',
    figsize=(20,10),
    title='Cities vs Avocado Sales per 100K 2018'
);
plt.ylabel("Sales per 100K population")
plt.show()

result2019.plot(
    y = 'Sales per 100K',
    x = 'City',
    kind='bar',
    figsize=(20,10),
    title='Cities vs Avocado Sales per 100K 2019'
);
plt.ylabel("Sales per 100K population")
plt.show()

result2020.plot(
    y = 'Sales per 100K',
    x = 'City',
    kind='bar',
    figsize=(20,10),
    title='Avocado Sales per 100K in Cities'
);
plt.ylabel("Sales per 100K population")
plt.show()

# %% [markdown]
# We confirmed that there is variability in sales from different cities, we would like to see the relationship between sales and age of the population. As we see throughout the years, the majority of the cities have consistant sales of avocado per 100 thousands population. There are few cities that have noticible changes like San Francisco, where from 2018 to 2019, there is increase in sales, but the following year, there is a dramatic decrease. Majority of the cities that we are researching seem to have minimal sales of avocadoes, averaging around .5-2 on our y-axis, and that the data might be skewed because of the large data outliers.
#
#
# Scatterplot can visually represent the relationship of age and avocado sales of each cities. Below we create a scatterplot graph of Median age vs Sales per 100K. We hope to see that there exist some plots on the top left corner (low median age and high sales volume) and bottom right corner (high median age and low sales volume).

# %%
## ScatterGraph Median vs Sales/Population in year
df2018 = result2018
df2018 = df2018.rename(columns={'Sales per 100K': "SalesPerHundredK", 'Median age (years)':'MedianAge'})
outcome, predictors = patsy.dmatrices('SalesPerHundredK ~ MedianAge', df2018)
# Now use statsmodels to intialize an OLS linear model
mod_log = sm.OLS(outcome, predictors)
# fit the model
res_log = mod_log.fit()


sns.scatterplot(x='MedianAge', y='SalesPerHundredK', alpha=0.5, data=df2018, s=100)
# Generate and plot the model fit line
xs = np.arange(df2018['MedianAge'].min(), df2018['MedianAge'].max())
ys =  7.191e+04 * xs + 4.925e+05
plt.plot(xs, ys, '--k', linewidth=4, label='Model')
plt.title("Sales in 100K vs Median Age(year) of 2018")
plt.xlabel('Median Age (Year)')
plt.ylabel('Sales per 100 K')
plt.legend();

X = df2018["MedianAge"]
Y = df2018["SalesPerHundredK"]
annotations= df2018["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
    
plt.show()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       SalesPerHundredK   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.023
# Method:                 Least Squares   F-statistic:                    0.2213
# Date:                Thu, 04 Mar 2021   Prob (F-statistic):              0.641
# Time:                        21:04:05   Log-Likelihood:                -556.53
# No. Observations:                  35   AIC:                             1117.
# Df Residuals:                      33   BIC:                             1120.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.925e+05   5.31e+06      0.093      0.927   -1.03e+07    1.13e+07
# MedianAge   7.191e+04   1.53e+05      0.470      0.641   -2.39e+05    3.83e+05
# ==============================================================================
# Omnibus:                        4.652   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.098   Jarque-Bera (JB):                4.370
# Skew:                           0.834   Prob(JB):                        0.112
# Kurtosis:                       2.539   Cond. No.                         545.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - From the scatter plot, we interpret that majority of the cities from our data around the age of 35 and estimate to have sales of avocados per 100 thousands population of about 2-3 millions in 2018.
#
#
# - P-value 0.641 shows that Sales per 100K and Median age (years) have no significance. From the given graph, we see that the for the year of 2018, there is a positive correlation between Sales per 100k and Median Age.

# %% [markdown]
# The scatterplot above has Median Age on the X-axis and Sales per 100K on the Y-axis (in 1E6 dollars). The plots on the graphs look quite evenly distributed. We will graph 2019 and 2020 and make comparisons.

# %%
## ScatterGraph Median vs Sales/Population in year
df2019 = result2019
df2019 = df2019.rename(columns={'Sales per 100K': "SalesPerHundredK", 'Median age (years)':'MedianAge'})
outcome, predictors = patsy.dmatrices('SalesPerHundredK ~ MedianAge', df2019)
# Now use statsmodels to intialize an OLS linear model
mod_log = sm.OLS(outcome, predictors)
# fit the model
res_log = mod_log.fit()



sns.scatterplot(x='MedianAge', y='SalesPerHundredK', alpha=0.5, data=df2019, s=100)
# Generate and plot the model fit line
xs = np.arange(df2019['MedianAge'].min(), df2019['MedianAge'].max())
ys =  -2.453e+04 * xs + 3.696e+06
plt.plot(xs, ys, '--k', linewidth=4, label='Model')
plt.title("Sales in 100K vs Median Age(year) of 2019")
plt.xlabel('Median Age (Year)')
plt.ylabel('Sales per 100 K')
plt.legend();

X = df2019["MedianAge"]
Y = df2019["SalesPerHundredK"]
annotations= df2019["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
    
plt.show()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       SalesPerHundredK   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                   0.03134
# Date:                Thu, 04 Mar 2021   Prob (F-statistic):              0.861
# Time:                        21:04:06   Log-Likelihood:                -553.09
# No. Observations:                  35   AIC:                             1110.
# Df Residuals:                      33   BIC:                             1113.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.696e+06   4.82e+06      0.767      0.448    -6.1e+06    1.35e+07
# MedianAge  -2.453e+04   1.39e+05     -0.177      0.861   -3.06e+05    2.57e+05
# ==============================================================================
# Omnibus:                        3.895   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.143   Jarque-Bera (JB):                3.592
# Skew:                           0.737   Prob(JB):                        0.166
# Kurtosis:                       2.459   Cond. No.                         545.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - From the scatter plot, most data points are near the bottom of the middle of the graph. We interpret that the majority of the cities from our data around the age of 34 and 36 with estimaion that have sales of avocados per 100 thousands population of about 1-2 millions in 2019.
#
#
# - P-value 0.861 shows that Sales per 100K and Median age (years) have no significance.

# %% [markdown]
# From the 2020 scatterplot, we did observe more plots on the top left corner compared to the bottom right corner. However, that could be skewed because of Miami (has the highest median age). From the scatterplot, we do not see any linear lines and thus we do not have a positive/negative correlation

# %%
## ScatterGraph Median vs Sales/Population in year

df2020 = result2020
df2020 = df2020.rename(columns={'Sales per 100K': "SalesPerHundredK", 'Median age (years)':'MedianAge'})
outcome, predictors = patsy.dmatrices('SalesPerHundredK ~ MedianAge', df2020)
# Now use statsmodels to intialize an OLS linear model
mod_log = sm.OLS(outcome, predictors)
# fit the model
res_log = mod_log.fit()

sns.scatterplot(x='MedianAge', y='SalesPerHundredK', alpha=0.5, data=df2020, s=100)

# Generate and plot the model fit line
xs = np.arange(df2020['MedianAge'].min(), df2020['MedianAge'].max())
ys = -6.748e+04 * xs + 4.865e+06
plt.plot(xs, ys, '--k', linewidth=4, label='Model')
plt.title("Sales in 100K vs Median Age(year) of 2020")
plt.xlabel('Median Age (Year)')
plt.ylabel('Sales per 100 K')
plt.legend();

X = df2020["MedianAge"]
Y = df2020["SalesPerHundredK"]
annotations= df2020["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
    
plt.show()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       SalesPerHundredK   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.022
# Method:                 Least Squares   F-statistic:                    0.2548
# Date:                Thu, 04 Mar 2021   Prob (F-statistic):              0.617
# Time:                        21:04:07   Log-Likelihood:                -551.83
# No. Observations:                  35   AIC:                             1108.
# Df Residuals:                      33   BIC:                             1111.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.865e+06   4.65e+06      1.047      0.303   -4.59e+06    1.43e+07
# MedianAge  -6.748e+04   1.34e+05     -0.505      0.617   -3.39e+05    2.05e+05
# ==============================================================================
# Omnibus:                        5.556   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                4.954
# Skew:                           0.921   Prob(JB):                       0.0840
# Kurtosis:                       2.945   Cond. No.                         545.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - From the scatter plot, most data points are near the bottom of the middle of the graph. We interpret that the majority of the cities from our data around the age of 34 and 37 with estimaion that have sales of avocados per 100 thousands population of about 500 thousands to 2 millions in 2020.
#
#
# - P-value 0.617 shows that Sales per 100K  and Median age (years) have no significance.

# %%
# income = income.sort_values(by=['15 to 24 years Median income (dollars)'])
# sns.set(rc={'figure.figsize':(20,20)})
# sns.barplot(x="15 to 24 years Median income (dollars)", y="City", data=income, orient="h")
# plt.show()

def standardizeStrToFloat(string):
    string = string.replace(',','')
    string = string.strip()
    return float(string)
income['15 to 24 years'] = income['15 to 24 years'].apply(standardizeStrToFloat).astype(int)
income['25 to 44 years'] = income['25 to 44 years'].apply(standardizeStrToFloat).astype(int)
income['45 to 64 years'] = income['45 to 64 years'].apply(standardizeStrToFloat).astype(int)
income['65 years and over'] = income['65 years and over'].apply(standardizeStrToFloat).astype(int)

income['15 to 24 years Median income (dollars)'] = income['15 to 24 years Median income (dollars)'].apply(standardizeStrToFloat)
income['25 to 44 years Median income (dollars)'] = income['25 to 44 years Median income (dollars)'].apply(standardizeStrToFloat)
income['45 to 64 years Median income (dollars)'] = income['45 to 64 years Median income (dollars)'].apply(standardizeStrToFloat)
income['65 years and over Median income (dollars)'] = income['65 years and over Median income (dollars)'].apply(standardizeStrToFloat)
print(income.dtypes)
# Out:
# City                                          object
# 15 to 24 years                                 int64
# 25 to 44 years                                 int64
# 45 to 64 years                                 int64
# 65 years and over                              int64
# 15 to 24 years Percent Distribution           object
# 25 to 44 years Percent Distribution           object
# 45 to 64 years Percent Distribution           object
# 65 years and over Percent Distribution        object
# 15 to 24 years Median income (dollars)       float64
# 25 to 44 years Median income (dollars)       float64
# 45 to 64 years Median income (dollars)       float64
# 65 years and over Median income (dollars)    float64
# dtype: object

# %%
income['Average of income'] = (
    income['15 to 24 years Median income (dollars)']*income['15 to 24 years'] 
    +income['25 to 44 years Median income (dollars)']*income['25 to 44 years'] 
    +income['45 to 64 years Median income (dollars)']*income['45 to 64 years']
    +income['65 years and over Median income (dollars)']*income['65 years and over']) / (income['15 to 24 years'] +income['25 to 44 years']+income['45 to 64 years'] + income['65 years and over']) 
income.head()
# Out:
#          City  15 to 24 years  25 to 44 years  45 to 64 years  \
# 0      Albany            5024           15963           12603
# 1     Atlanta           14128          100317           67256
# 2  Boise City            5754           34235           33335
# 3      Boston           16591          119768           81414
# 4   Charlotte           12798          151034          122508
#
#    65 years and over 15 to 24 years Percent Distribution  \
# 0               8818                              11.80%
# 1              42035                               6.30%
# 2              22035                               6.00%
# 3              53780                               6.10%
# 4              56108                               3.70%
#
#   25 to 44 years Percent Distribution 45 to 64 years Percent Distribution  \
# 0                              37.60%                              29.70%
# 1                              44.80%                              30.10%
# 2                              35.90%                              35.00%
# 3                              44.10%                              30.00%
# 4                              44.10%                              35.80%
#
#   65 years and over Percent Distribution  \
# 0                                 20.80%
# 1                                 18.80%
# 2                                 23.10%
# 3                                 19.80%
# 4                                 16.40%
#
#    15 to 24 years Median income (dollars)  \
# 0                                 31445.0
# 1                                 30336.0
# 2                                 38528.0
# 3                                 36194.0
# 4                                 37260.0
#
#    25 to 44 years Median income (dollars)  \
# 0                                 61132.0
# 1                                 80854.0
# 2                                 71744.0
# 3                                102558.0
# 4                                 66383.0
#
#    45 to 64 years Median income (dollars)  \
# 0                                 62915.0
# 1                                 71558.0
# 2                                 84309.0
# 3                                 85163.0
# 4                                 73650.0
#
#    65 years and over Median income (dollars)  Average of income
# 0                                    38123.0       53360.595996
# 1                                    46551.0       68424.812542
# 2                                    48762.0       68821.580941
# 3                                    38176.0       80537.600247
# 4                                    48454.0       64956.766382

# %%
income = income.sort_values(by=['Average of income'])
sns.set(rc={'figure.figsize':(20,20)})
sns.barplot(x="Average of income", y="City", data=income, orient="h")
plt.show()

# %%
compareIncomeSale2018 = pd.merge(left=result2018, right=income, how="left", on=["City"])
compareIncomeSale2019 = pd.merge(left=result2019, right=income, how="left", on=["City"])
compareIncomeSale2020 = pd.merge(left=result2020, right=income, how="left", on=["City"])


compareIncomeSale2018['Millennial Proportion'] = (
compareIncomeSale2018['25 to 29 years'] + compareIncomeSale2018['30 to 34 years'] + compareIncomeSale2018['35 to 39 years']) / compareIncomeSale2018['Total population'] 

compareIncomeSale2019['Millennial Proportion'] = (
compareIncomeSale2019['25 to 29 years'] + compareIncomeSale2019['30 to 34 years'] + compareIncomeSale2019['35 to 39 years']) / compareIncomeSale2019['Total population'] 

compareIncomeSale2020['Millennial Proportion'] = (
compareIncomeSale2020['25 to 29 years'] + compareIncomeSale2020['30 to 34 years'] + compareIncomeSale2020['35 to 39 years']) / compareIncomeSale2020['Total population'] 

compareIncomeSale2020.head()
# Out:
#          City  Average Price Per Unit   4046 Units   4225 Units  4770 Units  \
# 0      Albany                1.346875    459280.28   5566694.14     9244.96
# 1     Atlanta                1.207813  18429437.70   1608588.90    19030.56
# 2  Boise City                1.416979   1822009.32    423510.81    74476.34
# 3      Boston                1.603750    972456.99  24013739.81    30757.24
# 4   Charlotte                1.339271   7650208.66   3079177.77   224453.13
#
#    Total Sales ($)            State  Total population  Under 5 years  \
# 0     6.994118e+06         New York             97478           5622
# 1     1.837545e+07          Georgia            488800          26577
# 2     2.652730e+06            Idaho            226115          12985
# 3     3.386215e+07    Massachusetts            684379          34485
# 4     1.226594e+07   North Carolina            857425          57891
#
#    5 to 9 years  ...  15 to 24 years Percent Distribution  \
# 0          4667  ...                               11.80%
# 1         27559  ...                                6.30%
# 2         13588  ...                                6.00%
# 3         28298  ...                                6.10%
# 4         56536  ...                                3.70%
#
#    25 to 44 years Percent Distribution  45 to 64 years Percent Distribution  \
# 0                               37.60%                               29.70%
# 1                               44.80%                               30.10%
# 2                               35.90%                               35.00%
# 3                               44.10%                               30.00%
# 4                               44.10%                               35.80%
#
#    65 years and over Percent Distribution  \
# 0                                  20.80%
# 1                                  18.80%
# 2                                  23.10%
# 3                                  19.80%
# 4                                  16.40%
#
#    15 to 24 years Median income (dollars)  \
# 0                                 31445.0
# 1                                 30336.0
# 2                                 38528.0
# 3                                 36194.0
# 4                                 37260.0
#
#    25 to 44 years Median income (dollars)  \
# 0                                 61132.0
# 1                                 80854.0
# 2                                 71744.0
# 3                                102558.0
# 4                                 66383.0
#
#    45 to 64 years Median income (dollars)  \
# 0                                 62915.0
# 1                                 71558.0
# 2                                 84309.0
# 3                                 85163.0
# 4                                 73650.0
#
#    65 years and over Median income (dollars)  Average of income  \
# 0                                    38123.0       53360.595996
# 1                                    46551.0       68424.812542
# 2                                    48762.0       68821.580941
# 3                                    38176.0       80537.600247
# 4                                    48454.0       64956.766382
#
#    Millennial Proportion
# 0               0.220573
# 1               0.283054
# 2               0.231347
# 3               0.314054
# 4               0.257474
#
# [5 rows x 43 columns]

# %%
## ScatterGraph Average of income vs Sales/Population in year
df2018 = compareIncomeSale2018
df2018 = df2018.rename(columns={'Sales per 100K': "SalesPerHundredK", 'Average of income':'AverageIncome',})
outcome, predictors = patsy.dmatrices('SalesPerHundredK ~ AverageIncome', df2018)
# Now use statsmodels to intialize an OLS linear model
mod_log = sm.OLS(outcome, predictors)
# fit the model
res_log = mod_log.fit()


sns.scatterplot(x='AverageIncome', y='SalesPerHundredK', alpha=0.5, data=df2018, s=100)
# Generate and plot the model fit line
xs = np.arange(df2018['AverageIncome'].min(), df2018['AverageIncome'].max())
ys =  17.7119 * xs + 1.883e+06
plt.plot(xs, ys, '--k', linewidth=4, label='Model')
plt.title("Sales per 100K vs Average of income of 2018")
plt.xlabel('Average of income')
plt.ylabel('Sales per 100 K')
plt.legend();

X = df2018["AverageIncome"]
Y = df2018["SalesPerHundredK"]
annotations= df2018["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
    
plt.show()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       SalesPerHundredK   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.8511
# Date:                Thu, 04 Mar 2021   Prob (F-statistic):              0.363
# Time:                        21:04:09   Log-Likelihood:                -556.20
# No. Observations:                  35   AIC:                             1116.
# Df Residuals:                      33   BIC:                             1120.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1.883e+06   1.24e+06      1.515      0.139   -6.46e+05    4.41e+06
# AverageIncome    17.7119     19.199      0.923      0.363     -21.349      56.773
# ==============================================================================
# Omnibus:                        6.145   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                5.474
# Skew:                           0.969   Prob(JB):                       0.0647
# Kurtosis:                       3.033   Cond. No.                     2.40e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## ScatterGraph Average of income vs Sales/Population in year
df2019 = compareIncomeSale2019
df2019 = df2019.rename(columns={'Sales per 100K': "SalesPerHundredK", 'Average of income':'AverageIncome'})
outcome, predictors = patsy.dmatrices('SalesPerHundredK ~ AverageIncome', df2019)
# Now use statsmodels to intialize an OLS linear model
mod_log = sm.OLS(outcome, predictors)
# fit the model
res_log = mod_log.fit()


sns.scatterplot(x='AverageIncome', y='SalesPerHundredK', alpha=0.5, data=df2019, s=100)
# Generate and plot the model fit line
xs = np.arange(df2019['AverageIncome'].min(), df2019['AverageIncome'].max())
ys =  20.6736 * xs + 1.556e+06
plt.plot(xs, ys, '--k', linewidth=4, label='Model')
plt.title("Sales per 100K vs Average of income of 2019")
plt.xlabel('Average of income')
plt.ylabel('Sales per 100 K')
plt.legend();

X = df2019["AverageIncome"]
Y = df2019["SalesPerHundredK"]
annotations= df2019["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
    
plt.show()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       SalesPerHundredK   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.444
# Date:                Thu, 04 Mar 2021   Prob (F-statistic):              0.238
# Time:                        21:04:10   Log-Likelihood:                -552.36
# No. Observations:                  35   AIC:                             1109.
# Df Residuals:                      33   BIC:                             1112.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1.556e+06   1.11e+06      1.397      0.172    -7.1e+05    3.82e+06
# AverageIncome    20.6736     17.204      1.202      0.238     -14.328      55.675
# ==============================================================================
# Omnibus:                        3.845   Durbin-Watson:                   1.749
# Prob(Omnibus):                  0.146   Jarque-Bera (JB):                3.509
# Skew:                           0.755   Prob(JB):                        0.173
# Kurtosis:                       2.649   Cond. No.                     2.40e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## ScatterGraph Average of income vs Sales/Population in year
df2020 = compareIncomeSale2020
df2020 = df2020.rename(columns={'Sales per 100K': "SalesPerHundredK", 'Average of income':'AverageIncome'})
outcome, predictors = patsy.dmatrices('SalesPerHundredK ~ AverageIncome', df2020)
# Now use statsmodels to intialize an OLS linear model
mod_log = sm.OLS(outcome, predictors)
# fit the model
res_log = mod_log.fit()


sns.scatterplot(x='AverageIncome', y='SalesPerHundredK', alpha=0.5, data=df2020, s=100)
# Generate and plot the model fit line
xs = np.arange(df2020['AverageIncome'].min(), df2020['AverageIncome'].max())
ys =  2.1640 * xs + 2.389e+06
plt.plot(xs, ys, '--k', linewidth=4, label='Model')
plt.title("Sales per 100K vs Average of income of 2020")
plt.xlabel('Average of income')
plt.ylabel('Sales per 100 K')
plt.legend();

X = df2020["AverageIncome"]
Y = df2020["SalesPerHundredK"]
annotations= df2020["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
    
plt.show()
print(res_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       SalesPerHundredK   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.030
# Method:                 Least Squares   F-statistic:                   0.01619
# Date:                Thu, 04 Mar 2021   Prob (F-statistic):              0.900
# Time:                        21:04:11   Log-Likelihood:                -551.96
# No. Observations:                  35   AIC:                             1108.
# Df Residuals:                      33   BIC:                             1111.
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      2.389e+06    1.1e+06      2.170      0.037    1.49e+05    4.63e+06
# AverageIncome     2.1640     17.009      0.127      0.900     -32.441      36.769
# ==============================================================================
# Omnibus:                        5.632   Durbin-Watson:                   1.643
# Prob(Omnibus):                  0.060   Jarque-Bera (JB):                4.974
# Skew:                           0.923   Prob(JB):                       0.0831
# Kurtosis:                       2.987   Cond. No.                     2.40e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.4e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.scatterplot(x='Millennial Proportion', y='Sales per 100K',data=compareIncomeSale2018)

plt.title("Sales per 100K vs Millennial Proportion of 2020")
plt.xlabel('Millennial Proportion')
plt.ylabel('Sales per 100 K')

X = compareIncomeSale2018["Millennial Proportion"]
Y = compareIncomeSale2018["Sales per 100K"]
annotations= compareIncomeSale2018["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
plt.show()

# %%
sns.scatterplot(x='Millennial Proportion', y='Sales per 100K',data=compareIncomeSale2019)

plt.title("Sales per 100K vs Millennial Proportion of 2019")
plt.xlabel('Millennial Proportion')
plt.ylabel('Sales per 100 K')

X = compareIncomeSale2019["Millennial Proportion"]
Y = compareIncomeSale2019["Sales per 100K"]
annotations= compareIncomeSale2019["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
plt.show()

# %%
sns.scatterplot(x='Millennial Proportion', y='Sales per 100K',data=compareIncomeSale2020)

plt.title("Sales per 100K vs Millennial Proportion of 2020")
plt.xlabel('Millennial Proportion')
plt.ylabel('Sales per 100 K')

X = compareIncomeSale2020["Millennial Proportion"]
Y = compareIncomeSale2020["Sales per 100K"]
annotations= compareIncomeSale2020["City"]
for i, label in enumerate(annotations):
    plt.annotate(label, (X[i], Y[i]))
plt.show()

# %%
## ScatterGraph Median, Millennial Proportion, AverageIncome vs Sales/Population in year
df2020 = compareIncomeSale2020
df2020 = df2020.rename(columns={'Sales per 100K': "SalesPerHundredK", 'Millennial Proportion':'MillennialProportion','Average of income':'AverageIncome','Median age (years)':'MedianAge'})

outcome, predictors = patsy.dmatrices('SalesPerHundredK ~ MillennialProportion + AverageIncome + MedianAge ', df2020)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       SalesPerHundredK   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.067
# Method:                 Least Squares   F-statistic:                    0.2844
# Date:                Thu, 04 Mar 2021   Prob (F-statistic):              0.836
# Time:                        21:04:13   Log-Likelihood:                -551.49
# No. Observations:                  35   AIC:                             1111.
# Df Residuals:                      31   BIC:                             1117.
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             1.922e+06   6.14e+06      0.313      0.756   -1.06e+07    1.44e+07
# MillennialProportion  1.028e+07   1.38e+07      0.748      0.460   -1.78e+07    3.83e+07
# AverageIncome           -8.8346     24.589     -0.359      0.722     -58.985      41.316
# MedianAge             -4.39e+04   1.45e+05     -0.303      0.764   -3.39e+05    2.51e+05
# ==============================================================================
# Omnibus:                        7.681   Durbin-Watson:                   1.543
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                6.608
# Skew:                           1.041   Prob(JB):                       0.0367
# Kurtosis:                       3.442   Cond. No.                     3.07e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
